# %% [markdown]
# <center style=color:Green;font-size:40px>CAPSTONE</center>

# %% [markdown]
# <center><h2>BATTLE_OF_NEIGHBORHOOD</h2><center>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;<sub> -name of project</sub>

# %%
import pandas as pd
import numpy as np
import  matplotlib as mlt
import matplotlib.pyplot as plt

# %%
print("Hello Capstone Project Course!!")
# Out:
# Hello Capstone Project Course!!
